# %% [markdown]
# This analysis will be performed on all 8 stocks (NVDA, WOK,..). After analyzing the stock data, the results will draw conclusions on which 3 stocks out of the selected 8 would be potentially good to invest in as an investor.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
from pymongo import MongoClient
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Import the mongo log in
from cindy_private import cindy

# %% [markdown]
# This section presents the stock price trend using a **candlestick chart** for Q4 and January of 2025. The visualization provides insights into:
# - **Price fluctuations** over time.
# - **Volume trends** to understand trading activity.
# - Potential **spikes or volatility** that might indicate significant events.
#
# We can observe key price movements and trading behaviors to assist in making informed financial decisions.

# %%
# Read the stock visualizations 
nvda1 = mpimg.imread('../images/nvda1.png')
wok1 = mpimg.imread('../images/wok1.png')
yibo1 = mpimg.imread('../images/kirsten_images/yibo_price_trend_q4.png')
avgx1 = mpimg.imread('../images/kirsten_images/avgx_price_trend_q4.png')
akro1 = mpimg.imread('../images/akro_price_trend_q4.png')
nro1 = mpimg.imread('../images/nro_price_trend_q4.png')
dwtx1 = mpimg.imread("../David's_work/david_images/DWTX.png")
elab1 = mpimg.imread("../David's_work/david_images/ELAB.png")

# %%
# Display the image
plt.imshow(nvda1)
plt.axis('off')  # Hide axes
plt.show()

# %%
# Display the image
plt.imshow(wok1)
plt.axis('off')  # Hide axes
plt.show()

# %%
# Display the image
plt.imshow(yibo1)
plt.axis('off')  # Hide axes
plt.show()

# %%
# Display the image
plt.imshow(avgx1)
plt.axis('off')  # Hide axes
plt.show()

# %%
# Display the image
plt.imshow(akro1)
plt.axis('off')  # Hide axes
plt.show()

# %%
# Display the image
plt.imshow(nro1)
plt.axis('off')  # Hide axes
plt.show()

# %%
# Display the image
plt.imshow(dwtx1)
plt.axis('off')  # Hide axes
plt.show()

# %%
# Display the image
plt.imshow(elab1)
plt.axis('off')  # Hide axes
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Display the image
# ----> 2 plt.imshow(elab1)
#       3 plt.axis('off')  # Hide axes
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **NVDA stock price**
# - The **NVDA stock price** had a gradual increase in October with an average closing price of approximately $117 per stock on 10/1/2024 to an average closing price of approximately $132 per stock on 10/31/2024 (first month of the 4th quarter) and then fluctuated between an average closing price of approximately $132 per stock and $148 per stock in November. In December, the price fluctuated between an average closing price of approximately $128 per stock and $145 per stock.
# - During November and December, the stock experienced **notable price spikes**, suggesting increased volatility.
# - The average trade volume remained steady as the price of the stock increased in October of 2024. The average trade volume per day in November also remained steady as the price of the stock fluctuated noting an average trade volume of 400M on 11/21/2024 but the price of the stock increased to an average closing price of approximately $146 which is an increase of approximately $1 from the previous day. The average trade volume remained steady as the price of the stock fluctuated in December of 2024.
# - The stock showed **mostly steady movement** in October with a sideways trend in November and December. The late-year spikes indicate potential changes in investor sentiment.
# - Further analysis is needed to determine **volatility patterns** and possible **correlations** with market trends.

# %% [markdown]
# **WOK stock price**
# - shows an uptrend in October with an average closing price of approximately $4.80 per stock on 10/1/2024 to an average closing price of approximately $6 per stock on 10/31/2024 and then fluctuated between an average closing price of approximately $5.29 per stock and $6.42 per stock in November showing a sideways trend. Note that the volume of trade remained steady showing minimal trade activity during October and November. By December the average closing price was approximately $5.47 per stock and by 12/11/2024, it can be noted that the volume increased to approximately 1M shares traded and the price movement shows a price spike high for the day of approximately $8.80 per stock. The price of the stock spiked downward to a low of approximately $3.64 onthe following day. The volume traded continues to fluctuate as well following the same movement as the downward trend observed in December after 12/11/2024.
# - In January of 2025 it is noted that there was another increase in volume traded on 1/27/2025 as well as a sharp decrease in price from an opening price of $4.57 to low of approximately $2.70. The trade volume for that day was approximatly 862M shares indicating large amounts of shares being sold.

# %% [markdown]
# **AVGX stock price**
# - A significant **breakout occurred in late December**, with AVGX jumping from **$20 to over $35**.
# - The **rising moving averages** indicate **sustained bullish momentum**, though recent **volatility and sell-offs** suggest profit-taking or external market influence.
# - **December & January saw a major volume surge**, aligning with the price increase.
# - This may indicate **institutional accumulation**, news-driven events, or increased retail speculation.

# %% [markdown]
# **YIBO stock price**
# - The stock remained relatively stable with minimal fluctuations.
# - A sharp increase in price and volume was observed toward the end of January 2025, suggesting renewed investor interest.
# - YIBO exhibited notable volatility, particularly in early Q1.
# - Market events or speculative trading likely influenced the stock’s movements.
# - Further analysis is needed to determine correlations with external market indices and industry trends.

# %% [markdown]
# **NRO stock price**
# - NRO's stock price increased from $3.10 on January 2, 2024, to $3.39 on January 28, 2025, <br>
# reflecting a modest appreciation over the period
# - The stock experienced fluctuations, reaching a high of $4.15 and a low of $2.99 during the <br>
# 52-week period ending January 31, 2025.
# - Throughout this period, NRO maintained a monthly dividend of $0.0312 per share, resulting in <br>
# an annualized distribution rate of approximately 10.98% as of January 31, 2025.

# %% [markdown]
# **AKRO stock price**
# - Overall, AKRO's stock demonstrated resilience with a general upward trend throughout 2024, despite some volatility. <br>
# The company began the year at $23.48 and concluded at $29.15, reflecting a positive trajectory.
#
# - As of January 28, 2025, AKRO's stock is trading at $51.47, indicating a significant increase from its 2024 closing price.

# %% [markdown]
# **DWTX stock price**
# - Stock price of ELAB has shown negative movements for the most part.
# - It is not able to be at a stable state.
# - There was no increase in volume during the whole time the stock price was decreasing.
# - Only when the price shot up in a spike did an increase of volume followed.
# - There is some volatitity, ther has been a big spike during the time the price was decreasing, and again in mid November
# - I found it interesting that there was no increase of volume when there was a spike in December 2023.

# %% [markdown]
# **ELAB stock price**
# - For the first half, it price has been very stable.
# - the price increased during halfway and has been trying to stable after that.
# - As mentioned before, the stock price has been decreasing for the most part, and then a suddeny price increase in November.

# %%
x = ['NVDA','WOK','AKRO','NRO','DWTX','ELAB','YIBO','AVGX']
y = [0.03283224344929463,0.08192654473732675, 0.11427781386362572,0.01514379631153504,1.9736113636989896,21.446091404835467,0.13094518562649393,0.08410979745833297]

plt.bar(x,y, color=['blue', 'red','green','purple','orange','pink','teal','yellow'])
plt.ylabel('Standard Deviation of Returns')
plt.title('Volatility Comparison (Oct 2024 Onward)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### 🔹 Observations:
# - **ELAB exhibits higher volatility** amongst all 8 stocks, as indicated by its higher standard deviation of returns.
# - This suggests that **ELAB’s price movements are more erratic**, making it a riskier but potentially more rewarding stock for traders.

# %% [markdown]
# As a long-term investor, the goal is to diversify your portfolio with both high risk and low risk stocks.
# - DWTX's stock price has strong potential to increase in the future with medium risk due to their volatility and this may give diversity to the portfolio.
# - ELAB's stock price shows potential for growth and has a significantly higher volatility out of all 8 stocks making it a high risk stock. This can help diversify the overall portfolio for a potentially higher reward.
# - NVDA's stock price has historically grown over time and has a relatively lower risk due to their low volatility and this may bring stability to the overal portfolio.
# - AVGX's stock price has strong potential to increase in the future while remaining stable over time from their low volatility which may bring stability to the portfolio.

# %% [markdown]
# Some stocks were eliminated early on in the stock bowl so the purpose of this analysis is to compare all 8 against eachother to see which one would be the top 4. It appears that the top 4 stocks in this analysis includes one of the stocks that were eliminated (ELAB)
